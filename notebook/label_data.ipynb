# %%
import pandas as pd
import os

os.chdir('../')

# %%
df = pd.read_csv(r'data\subset_cyh\restaurant_decisions_v2.csv')
df
# Out:
#      Unnamed: 0                                                url  \
# 0          8440  https://www.zomato.com/bangalore/kalingas-btm?...
# 1         23575  https://www.zomato.com/bangalore/angel-restaur...
# 2         16711  https://www.zomato.com/bangalore/cafe-talkhous...
# 3         42588  https://www.zomato.com/bangalore/paratha-xpres...
# 4          5266  https://www.zomato.com/bangalore/classic-lassi...
# ..          ...                                                ...
# 995       20902  https://www.zomato.com/bangalore/healthy-bakes...
# 996       38130  https://www.zomato.com/bangalore/red-lantern-c...
# 997       41726  https://www.zomato.com/bangalore/kaafi-desi-ma...
# 998       33721  https://www.zomato.com/bangalore/brownie-point...
# 999       13253  https://www.zomato.com/bangalore/ice-taj-mg-ro...
#
#                                                address  \
# 0            399, 16th Main, N.S Palya, BTM, Bangalore
# ...

# %%
df.iloc[:, -10:]
# compute row averages
df['preference'] = df.iloc[:, -10:].mean(axis=1)
df['preference']
# Out:
# 0      0.2
# 1      0.3
# 2      0.0
# 3      0.5
# 4      0.0
#       ...
# 995    0.0
# 996    0.0
# 997    0.5
# 998    0.0
# 999    0.0
# Name: preference, Length: 1000, dtype: float64

# %%
df['preference'].value_counts()
# Out:
# preference
# 0.0    488
# 0.1    197
# 0.3    126
# 0.4     79
# 0.5     78
# 0.2     19
# 0.6     10
# 0.7      3
# Name: count, dtype: int64

# %%
pd.unique(df['location'])
# Out:
# array(['BTM', 'Bannerghatta Road', 'HSR', 'Ulsoor', 'Banaswadi',
#        'Jayanagar', 'Koramangala 4th Block', 'Richmond Road',
#        'Frazer Town', 'Koramangala 5th Block', 'Thippasandra',
#        'Lavelle Road', 'Kammanahalli', 'Brigade Road', 'St. Marks Road',
#        'Whitefield', 'Shivajinagar', 'Ejipura', 'Residency Road',
#        'Marathahalli', 'Koramangala 6th Block', 'Basavanagudi',
#        'Koramangala 1st Block', 'New BEL Road', 'Sarjapur Road',
#        'Bommanahalli', 'Banashankari', 'Koramangala 7th Block',
#        'JP Nagar', 'Kumaraswamy Layout', 'Domlur', 'Electronic City',
#        'Brookefield', 'Indiranagar', 'Jeevan Bhima Nagar',
#        'Basaveshwara Nagar', 'Koramangala 8th Block', 'Wilson Garden',
#        'Cunningham Road', 'Kalyan Nagar', 'Bellandur', 'Koramangala',
#        'Rajajinagar', 'Shanti Nagar', 'Church Street', 'Sahakara Nagar',
#        'Infantry Road', 'Kaggadasapura', 'Hennur', 'Vasanth Nagar',
# ...
